# %% [markdown]
# # KENV
#
# <a href=mailto:fuodorov1998@gmail.com>V. Fedorov</a>, <a href=mailto:nikdanila@bk.ru>D. Nikiforov</a>, <a href=http://www.inp.nsk.su/~petrenko/>A. Petrenko</a>, (Novosibirsk, 2019)

# %% [markdown]
# ## Genetic algorithm for building an envelope
# Sometimes it’s useful to use a computer to adjust the envelope.

# %% [markdown]
# Genetic algorithms work similarly to natural selection in nature. The basis of the genetic algorithm is the individual, chromosomes (genes), population (set of individuals), the functions of adaptability, selection, crossing and mutation. In practice, everything happens like this: the creation of the first generation, assessment, selection, crossing, mutation, new generation, evaluation, etc. until we get the desired result.
#
# DEAP is a framework for working with genetic algorithms, containing many ready-made tools, the main thing is to know how to use them.

# %% [markdown]
# ## Create a beam and accelerator.

# %%
import kenv as kv

# %%
beam = kv.Beam(energy=2,
               current=2e3,
               radius=50e-3,
               angular=50e-3,
               normalized_emittans=1000e-6)

# %%
accelerator = kv.Accelerator(0, 5, 0.01)

# %%
Solenoids = [ 
    [ 0.5000, 0.07, 'input/B_z(z).dat', 'Sol. 1'],
    [ 1.0000, 0.07, 'input/B_z(z).dat', 'Sol. 2'],
    [ 1.5000, 0.07, 'input/B_z(z).dat', 'Sol. 3'],
    [ 2.0000, 0.07, 'input/B_z(z).dat', 'Sol. 4'],
    [ 2.5000, 0.07, 'input/B_z(z).dat', 'Sol. 5'],
    [ 3.0000, 0.07, 'input/B_z(z).dat', 'Sol. 6'],
    [ 3.5000, 0.07, 'input/B_z(z).dat', 'Sol. 7'],
    [ 4.0000, 0.07, 'input/B_z(z).dat', 'Sol. 8'],
    [ 4.5000, 0.07, 'input/B_z(z).dat', 'Sol. 9'],
]

# %%
for   z0, B0, filename, name in Solenoids:
    accelerator.Bz_beamline[name] = kv.Element(z0, B0, filename, name)

# %%
accelerator.compile()
# Out:
# Accelerator compiled.

# %%
simulation = kv.Simulation(beam, accelerator)

# %%
simulation.track()
# Out:
# Tracking is completed.

# %% [markdown]
# ## Graphic

# %% [markdown]
# ### matplotlib

# %%
import holoviews as hv
hv.extension('matplotlib')

# %opts Layout [tight=True]
# %output size=150 backend='matplotlib' fig='svg'

# %opts Area Curve [aspect=3 show_grid=True]
# %opts Area  (alpha=0.25)
# %opts Curve (alpha=0.5)
# %opts Area.Beam [aspect=3 show_grid=True] (color='red' alpha=0.3)

import warnings
warnings.filterwarnings('ignore')
# Out:
# <link rel="stylesheet" href="https://code.jquery.com/ui/1.10.4/themes/smoothness/jquery-ui.css">
# <style>div.hololayout {
#   display: flex;
#   align-items: center;
#   margin: 0;
# }
#
# div.holoframe {
#   width: 75%;
# }
#
# div.holowell {
#   display: flex;
#   align-items: center;
# }
#
# form.holoform {
#   background-color: #fafafa;
#   border-radius: 5px;
#   overflow: hidden;
#   padding-left: 0.8em;
#   padding-right: 0.8em;
#   padding-top: 0.4em;
#   padding-bottom: 0.4em;
#   box-shadow: inset 0 1px 1px rgba(0, 0, 0, 0.05);
#   margin-bottom: 20px;
#   border: 1px solid #e3e3e3;
# }
#
# div.holowidgets {
#   padding-right: 0;
#   width: 25%;
# }
#
# div.holoslider {
#   min-height: 0 !important;
#   height: 0.8em;
#   width: 100%;
# }
#
# div.holoformgroup {
#   padding-top: 0.5em;
#   margin-bottom: 0.5em;
# }
#
# div.hologroup {
#   padding-left: 0;
#   padding-right: 0.8em;
#   width: 100%;
# }
#
# .holoselect {
#   width: 92%;
#   margin-left: 0;
#   margin-right: 0;
# }
#
# .holotext {
#   padding-left:  0.5em;
#   padding-right: 0;
#   width: 100%;
# }
#
# .holowidgets .ui-resizable-se {
#   visibility: hidden
# }
#
# .holoframe > .ui-resizable-se {
#   visibility: hidden
# }
#
# .holowidgets .ui-resizable-s {
#   visibility: hidden
# }
#
#
# /* CSS rules for noUISlider based slider used by JupyterLab extension  */
#
# .noUi-handle {
#   width: 20px !important;
#   height: 20px !important;
#   left: -5px !important;
#   top: -5px !important;
# }
#
# .noUi-handle:before, .noUi-handle:after {
#   visibility: hidden;
#   height: 0px;
# }
#
# .noUi-target {
#   margin-left: 0.5em;
#   margin-right: 0.5em;
# }
# </style>
#
#
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#
#
#   <img src='...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
# </div>

# %%
dim_z  = hv.Dimension('z',  unit='m', range=(accelerator.start, accelerator.stop))
dim_Bz = hv.Dimension('Bz', unit='T', label='Bz', range=(0, 0.1))
dim_Ez = hv.Dimension('Ez', unit='MV/m', label='Ez')

dim_r = hv.Dimension('r', label="Beam r", unit='mm', range=(0, 150))

# %%
z_Bz= hv.Area((accelerator.parameter,accelerator.Bz(accelerator.parameter)), kdims=[dim_z], vdims=[dim_Bz])
z_r = hv.Area(((accelerator.parameter,simulation.envelope_x*1e3)), kdims=[dim_z], vdims=[dim_r], group='Beam')

(z_r+z_Bz).cols(1)
# Out:
# :Layout
#    .Beam.I :Area   [z]   (r)
#    .Area.I :Area   [z]   (Bz)

# %% [markdown]
# As you can see, the envelope is far from perfect.
#
# Apply the genetic algorithm.

# %% [markdown]
# ## Genetic algorithm

# %% [markdown]
# First we construct a model envelope.

# %%
import numpy as np

coefficients = np.polyfit([accelerator.start, (accelerator.start+accelerator.stop)/2, accelerator.stop], [0.10, 0.05, 0.03], 2) 
envelope_mod = coefficients[0]*accelerator.parameter**2 +  coefficients[1]*accelerator.parameter+ coefficients[2]

z_env = hv.Curve((accelerator.parameter, envelope_mod*1e3), kdims=[dim_z], vdims=[dim_r], label='Envelope_mod', group='Beam')

# %%
z_env
# Out:
# :Curve   [z]   (r)

# %% [markdown]
# Connect the necessary libraries.

# %%
import random
from deap import creator, base, tools, algorithms

# %% [markdown]
# The first step is to create the necessary types. Usually it is fitness and the individual.

# %%
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", list, fitness=creator.FitnessMin)

# %% [markdown]
# Next, you need to create a toolkit. To do this, you need to set the basic parameters for our algorithm.

# %%
Sol_B = 0.07     # [T] average Bz in the solenoids
Sol_B_max = 0.1  # [T] max Bz
Sol_B_min = 0.03 # [T] min Bz
Sol_Num = 9     # quantity

Cxpb = 0.4       # cross chance
Mutpb = 0.6     # Mutation probability
Ngen = 100       # Number of generations
Pop = 100       # Number of individuals

# %%
toolbox = base.Toolbox()
toolbox.register("attr_float", random.gauss, Sol_B, ((Sol_B_max - Sol_B_min)/2)**2)
toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_float, n=Sol_Num)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

# %% [markdown]
# Create a fitness function.

# %%
def evalution_envelope(individual):

    for x in range(Sol_Num):
        accelerator.Bz_beamline['Sol. %.d'%(x+1)].max_field  = individual[x]
    
    accelerator.compile()
    simulation = kv.Simulation(beam, accelerator)
    simulation.track()
    
    tuple(envelope_mod)
    tuple(simulation.envelope_x)

    sqerrors = np.sqrt((envelope_mod-simulation.envelope_x)**2)
    
    return sum(sqerrors)/len(accelerator.parameter),

# %%
toolbox.register("evaluate", evalution_envelope)
toolbox.register("mate", tools.cxUniform, indpb=Mutpb )
toolbox.register("mutate", tools.mutGaussian, mu=0, sigma=((Sol_B_max - Sol_B_min)/2)**2, indpb=Mutpb)
toolbox.register("select", tools.selTournament, tournsize=Ngen//3)

# %% [markdown]
# Logbook.

# %%
stats_fit = tools.Statistics(lambda ind: ind.fitness.values)
mstats = tools.MultiStatistics(fitness=stats_fit)
mstats.register("avg", np.mean)
mstats.register("std", np.std)
mstats.register("min", np.min)
mstats.register("max", np.max)

logbook = tools.Logbook()

# %%
population = toolbox.population(n=Pop)

pop, logbook = algorithms.eaSimple(population, toolbox, cxpb=Cxpb, mutpb=Mutpb, ngen=Ngen, stats=mstats, verbose=True)
top = tools.selBest(pop, k=10)
gen = np.array(logbook.select("gen"))
fit_min = np.array(logbook.chapters["fitness"].select("min"))
fit_max = np.array(logbook.chapters["fitness"].select("max"))
fit_avg = np.array(logbook.chapters["fitness"].select("avg"));
# Out:
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
#    	      	                                  fitness
#    	      	---------------------------------------------------------------------------
# gen	nevals	avg      	gen	max      	min      	nevals	std
# 0  	100   	0.0241878	0  	0.0255394	0.0230286	100   	0.000510091
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# 1  	71    	0.0232476	1  	0.0245786	0.0223448	71    	0.000352311
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# 2  	78    	0.0225974	2  	0.0236461	0.0218011	78    	0.000294768
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# 3  	82    	0.022052 	3  	0.0227038	0.0215882	82    	0.000218606
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# 4  	76    	0.0216997	4  	0.0223487	0.0212654	76    	0.000173325
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# 5  	73    	0.0214087	5  	0.0219434	0.0209865	73    	0.000174927
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# 6  	74    	0.0211275	6  	0.0216381	0.0208492	74    	0.000146062
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# 7  	84    	0.0209299	7  	0.0215199	0.0205114	84    	0.00016695
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# 8  	75    	0.0206851	8  	0.0215928	0.0203445	75    	0.000224704
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# 9  	75    	0.0204537	9  	0.0214025	0.0201013	75    	0.000194257
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# 10 	75    	0.0202465	10 	0.0211622	0.0199368	75    	0.000212104
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# 11 	72    	0.020028 	11 	0.0212078	0.0197015	72    	0.000196316
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# 12 	78    	0.0198634	12 	0.0207032	0.0195472	78    	0.000202433
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# ...
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# 21 	80    	0.0188499	21 	0.0201468	0.0186709	80    	0.000281468
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# 22 	75    	0.0188604	22 	0.0212626	0.0186089	75    	0.000390178
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# 23 	74    	0.0188313	23 	0.020787 	0.0185447	74    	0.000323695
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# 24 	74    	0.0187205	24 	0.0195914	0.0184676	74    	0.000237282
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# Tracking is completed.
# Accelerator compiled.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-02904778fe5c> in <module>
#       2
#       3
# ----> 4 pop, logbook = algorithms.eaSimple(population, toolbox, cxpb=Cxpb, mutpb=Mutpb, ngen=Ngen, stats=mstats, verbose=True)
#       5 top = tools.selBest(pop, k=10)
#       6 gen = np.array(logbook.select("gen"))
#
# C:\ProgramData\Anaconda3\lib\site-packages\deap\algorithms.py in eaSimple(population, toolbox, cxpb, mutpb, ngen, stats, halloffame, verbose)
#     171         invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
#     172         fitnesses = toolbox.map(toolbox.evaluate, invalid_ind)
# --> 173         for ind, fit in zip(invalid_ind, fitnesses):
#     174             ind.fitness.values = fit
#     175
#
# <ipython-input-18-17fa4924522b> in evalution_envelope(individual)
#       6     accelerator.compile()
#       7     simulation = kv.Simulation(beam, accelerator)
# ----> 8     simulation.track()
#       9
#      10     tuple(envelope_mod)
#
# C:\ProgramData\Anaconda3\lib\site-packages\kenv\solver.py in track(self)
#     100         X0 = [self.radius_x, self.angular_x, self.radius_y, self.angular_y]
#     101         self.envelope_x = odeint(dXdz, X0, self.parameter, rtol=self.rtol)[0:,1]
# --> 102         self.envelope_y = odeint(dXdz, X0, self.parameter, rtol=self.rtol)[0:,3]
#     103
#     104         print('Tracking is completed.')
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\integrate\odepack.py in odeint(func, y0, t, args, Dfun, col_deriv, full_output, ml, mu, rtol, atol, tcrit, h0, hmax, hmin, ixpr, mxstep, mxhnil, mxordn, mxords, printmessg, tfirst)
#     242                              full_output, rtol, atol, tcrit, h0, hmax, hmin,
#     243                              ixpr, mxstep, mxhnil, mxordn, mxords,
# --> 244                              int(bool(tfirst)))
#     245     if output[-1] < 0:
#     246         warning_msg = _msgs[output[-1]] + " Run with full_output = 1 to get quantitative information."
#
# C:\ProgramData\Anaconda3\lib\site-packages\kenv\solver.py in dXdz(X, z, dz, gamma, Bz, Ez, Gz, beam_current, emitt_n_x, emitt_n_y, c, mc, alfven_current)
#      72             x, sigma_x, y, sigma_y = X[0], X[1], X[2], X[3]
#      73
# ---> 74             g = gamma(z)
#      75             dgdz = Ez(z) / mc
#      76             d2gdz2 = derivative(lambda z:Ez(z),z, dz) / mc
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\interpolate\polyint.py in __call__(self, x)
#      77         """
#      78         x, x_shape = self._prepare_x(x)
# ---> 79         y = self._evaluate(x)
#      80         return self._finish_y(y, x_shape)
#      81
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\interpolate\interpolate.py in _evaluate(self, x_new)
#     660         #    The behavior is set by the bounds_error variable.
#     661         x_new = asarray(x_new)
# --> 662         y_new = self._call(self, x_new)
#     663         if not self._extrapolate:
#     664             below_bounds, above_bounds = self._check_bounds(x_new)
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\interpolate\interpolate.py in _call_linear_np(self, x_new)
#     584     def _call_linear_np(self, x_new):
#     585         # Note that out-of-bounds values are taken care of in self._evaluate
# --> 586         return np.interp(x_new, self.x, self.y)
#     587
#     588     def _call_linear(self, x_new):
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py in interp(x, xp, fp, left, right, period)
#    1410         fp = np.concatenate((fp[-1:], fp, fp[0:1]))
#    1411
# -> 1412     return interp_func(x, xp, fp, left, right)
#    1413
#    1414
#
# KeyboardInterrupt:

# %%
for x in range(Sol_Num):
            accelerator.Bz_beamline['Sol. %.d'%(x+1)].max_field  = top[0][x]
        
accelerator.compile()
simulation = kv.Simulation(beam, accelerator)
simulation.track()

(z_r*z_env+z_Bz).cols(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-4b5d81440369> in <module>
#       1 for x in range(Sol_Num):
# ----> 2             accelerator.Bz_beamline['Sol. %.d'%(x+1)].max_field  = top[0][x]
#       3
#       4 accelerator.compile()
#       5 simulation = kv.Simulation(beam, accelerator)
#
# NameError: name 'top' is not defined
