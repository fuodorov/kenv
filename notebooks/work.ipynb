# %% [markdown]
# # KENV
#
# <a href=mailto:fuodorov1998@gmail.com>V. Fedorov</a>, <a href=mailto:nikdanila@bk.ru>D. Nikiforov</a>, <a href=http://www.inp.nsk.su/~petrenko/>A. Petrenko</a>, (Novosibirsk, 2019)

# %% [markdown]
# ## Manual

# %%
import kenv as kv

# %% [markdown]
# Сan call for help:

# %%
#help(kv)

# %% [markdown]
# ## Simulation
#
# To obtain an envelope, you need to create a beam and an accelerator. Then load the simulation of this beam in this accelerator and apply tracking.

# %%
#help(kv.Beam)

# %%
beam = kv.Beam(energy=2,
               current=2e3,
               radius=50e-3,
               angular=55.0e-3,
               normalized_emittans=1000e-6)

# %%
beam.add_particle('Center',30e-3,0, 0,0)

# %% [markdown]
# Can print:

# %%
print(beam)
# Out:
# Beam parameters:
# 	Current	2000.0 A
# 	Energy	2.0 MeV
# 	Radius x	50.0 mm
# 	Radius y	50.0 mm
# 	Angular x	55.0 mrad
# 	Angular y	55.0 mrad
# 	Normalized emittans x	1000.0 mm*mrad
# 	Normalized emittans y	1000.0 mm*mrad
# 	Particles:
# 	[ 30.0 mm, 0.0 mm, 0.0 mrad, 0.0 mrad, 0.0 rad, 'Center'],

# %%
#help(kv.Accelerator)

# %%
accelerator = kv.Accelerator(0.7, 17, 0.001)

# %%
Solenoids = [ 
    [ 0.45,       0.0,      'input/B_z(z).dat', 'Sol. 0' ],
    [ 0.95,       0.001,    'input/B_z(z).dat', 'Sol. 1' ],
    [ 2.1,        0.03,     'input/B_z(z).dat', 'Sol. 2' ],
    [ 2.9077,     0.001,    'input/B_z(z).dat', 'Sol. 3' ],
    [ 4.0024,     0.03,     'input/B_z(z).dat', 'Sol. 4' ],
    [ 5.642,      0.0250,   'input/B_z(z).dat', 'Sol. 5' ],
    [ 6.760,      0.001,    'input/B_z(z).dat', 'Sol. 6' ],
    [ 8.116,      0.000,    'input/B_z(z).dat', 'Sol. 7' ],
    [ 9.213,      0.000,    'input/B_z(z).dat', 'Sol. 8' ],
    [ 10.138,     0.000,    'input/B_z(z).dat', 'Sol. 9' ],
    [ 11.738,     0.000,    'input/B_z(z).dat', 'Sol. 10'],
    [ 12.776,     0.000,    'input/B_z(z).dat', 'Sol. 11'],
    [ 14.128,     0.000,    'input/B_z(z).dat', 'Sol. 12'],
]

# %%
Accels = [
    [ 4.692,       -0.9,     'input/E_z(z).dat',  'Cavity 1'],
    [ 6.076,       -0.9,     'input/E_z(z).dat',  'Cavity 2'],
    [ 7.456,       -0.9,     'input/E_z(z).dat',  'Cavity 3'],
    [ 8.838,       -0.9,     'input/E_z(z).dat',  'Cavity 4'],
    [ 10.220,      -0.9,     'input/E_z(z).dat',  'Cavity 5'],
    [ 11.602,      -0.9,     'input/E_z(z).dat',  'Cavity 6'],
    [ 12.984,      -0.9,     'input/E_z(z).dat',  'Cavity 7'],
    [ 14.366,      -0.9,     'input/E_z(z).dat',  'Cavity 8'],    
]

# %%
for   z0, B0, filename, name in Solenoids:
    accelerator.Bz_beamline[name] = kv.Element(z0, B0, filename, name)
for   z0, E0, filename, name in Accels:
    accelerator.Ez_beamline[name] = kv.Element(z0, E0, filename, name)

# %%
print(accelerator)
# Out:
# Accelerator structure.
# 	Solenoids:
# 	[ 0.45000 m, 0.00000 T, 'notebooks/input/B_z(z).dat', 'Sol. 0'],
# 	[ 0.95000 m, 0.00100 T, 'notebooks/input/B_z(z).dat', 'Sol. 1'],
# 	[ 2.10000 m, 0.03000 T, 'notebooks/input/B_z(z).dat', 'Sol. 2'],
# 	[ 2.90770 m, 0.00100 T, 'notebooks/input/B_z(z).dat', 'Sol. 3'],
# 	[ 4.00240 m, 0.03000 T, 'notebooks/input/B_z(z).dat', 'Sol. 4'],
# 	[ 5.64200 m, 0.02500 T, 'notebooks/input/B_z(z).dat', 'Sol. 5'],
# 	[ 6.76000 m, 0.00100 T, 'notebooks/input/B_z(z).dat', 'Sol. 6'],
# 	[ 8.11600 m, 0.00000 T, 'notebooks/input/B_z(z).dat', 'Sol. 7'],
# 	[ 9.21300 m, 0.00000 T, 'notebooks/input/B_z(z).dat', 'Sol. 8'],
# 	[ 10.13800 m, 0.00000 T, 'notebooks/input/B_z(z).dat', 'Sol. 9'],
# 	[ 11.73800 m, 0.00000 T, 'notebooks/input/B_z(z).dat', 'Sol. 10'],
# 	[ 12.77600 m, 0.00000 T, 'notebooks/input/B_z(z).dat', 'Sol. 11'],
# 	[ 14.12800 m, 0.00000 T, 'notebooks/input/B_z(z).dat', 'Sol. 12'],
# 	Accelerating modules:
# 	[ 4.69200 m, -0.90000 Mv/m, 'notebooks/input/E_z(z).dat', 'Cavity 1'],
# 	[ 6.07600 m, -0.90000 Mv/m, 'notebooks/input/E_z(z).dat', 'Cavity 2'],
# 	[ 7.45600 m, -0.90000 Mv/m, 'notebooks/input/E_z(z).dat', 'Cavity 3'],
# 	[ 8.83800 m, -0.90000 Mv/m, 'notebooks/input/E_z(z).dat', 'Cavity 4'],
# 	[ 10.22000 m, -0.90000 Mv/m, 'notebooks/input/E_z(z).dat', 'Cavity 5'],
# 	[ 11.60200 m, -0.90000 Mv/m, 'notebooks/input/E_z(z).dat', 'Cavity 6'],
# 	[ 12.98400 m, -0.90000 Mv/m, 'notebooks/input/E_z(z).dat', 'Cavity 7'],
# 	[ 14.36600 m, -0.90000 Mv/m, 'notebooks/input/E_z(z).dat', 'Cavity 8'],
# 	Quadrupoles:

# %%
accelerator.compile()

# %%
#help(kv.Simulation)

# %%
simulation = kv.Simulation(beam, accelerator)

# %%
simulation.track(solver='solve_ivp')

# %%
#simulation.envelope_x
#simulation.particle_phase['Center']

# %% [markdown]
# ## Graphic with holoviews

# %% [markdown]
# ### matplotlib

# %%
import holoviews as hv
hv.extension('matplotlib')

# %opts Layout [tight=True]
# %output size=150 backend='matplotlib' fig='png'

# %opts Area Curve [aspect=3 show_grid=True]
# %opts Area  (alpha=0.25)
# %opts Curve (alpha=0.5)
# %opts Area.Beam [aspect=3 show_grid=True] (color='red' alpha=0.3)

import warnings
warnings.filterwarnings('ignore')
# Out:
# <link rel="stylesheet" href="https://code.jquery.com/ui/1.10.4/themes/smoothness/jquery-ui.css">
# <style>div.hololayout {
#   display: flex;
#   align-items: center;
#   margin: 0;
# }
#
# div.holoframe {
#   width: 75%;
# }
#
# div.holowell {
#   display: flex;
#   align-items: center;
# }
#
# form.holoform {
#   background-color: #fafafa;
#   border-radius: 5px;
#   overflow: hidden;
#   padding-left: 0.8em;
#   padding-right: 0.8em;
#   padding-top: 0.4em;
#   padding-bottom: 0.4em;
#   box-shadow: inset 0 1px 1px rgba(0, 0, 0, 0.05);
#   margin-bottom: 20px;
#   border: 1px solid #e3e3e3;
# }
#
# div.holowidgets {
#   padding-right: 0;
#   width: 25%;
# }
#
# div.holoslider {
#   min-height: 0 !important;
#   height: 0.8em;
#   width: 100%;
# }
#
# div.holoformgroup {
#   padding-top: 0.5em;
#   margin-bottom: 0.5em;
# }
#
# div.hologroup {
#   padding-left: 0;
#   padding-right: 0.8em;
#   width: 100%;
# }
#
# .holoselect {
#   width: 92%;
#   margin-left: 0;
#   margin-right: 0;
# }
#
# .holotext {
#   padding-left:  0.5em;
#   padding-right: 0;
#   width: 100%;
# }
#
# .holowidgets .ui-resizable-se {
#   visibility: hidden
# }
#
# .holoframe > .ui-resizable-se {
#   visibility: hidden
# }
#
# .holowidgets .ui-resizable-s {
#   visibility: hidden
# }
#
#
# /* CSS rules for noUISlider based slider used by JupyterLab extension  */
#
# .noUi-handle {
#   width: 20px !important;
#   height: 20px !important;
#   left: -5px !important;
#   top: -5px !important;
# }
#
# .noUi-handle:before, .noUi-handle:after {
#   visibility: hidden;
#   height: 0px;
# }
#
# .noUi-target {
#   margin-left: 0.5em;
#   margin-right: 0.5em;
# }
# </style>
#
#
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#
#
#   <img src='...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
# </div>

# %%
dim_z  = hv.Dimension('z',  unit='m', range=(accelerator.start, accelerator.stop))
dim_Bz = hv.Dimension('Bz', unit='T', label='Bz')
dim_Ez = hv.Dimension('Ez', unit='MV/m', label='Ez')
dim_dEzdz = hv.Dimension('dEzdz', unit='$\mathrm{MV/m^2}$', label='$dE_z/dz$', range=(-10,+10))

dim_r = hv.Dimension('r', label="Beam r", unit='mm', range=(-50,50))
dim_phase = hv.Dimension('$\phi$', label="Larmor phase", unit='rad')

# %%
z_Ez = hv.Area((accelerator.parameter,accelerator.Ez(accelerator.parameter)), kdims=dim_z, vdims=dim_Ez)
z_dEzdz = hv.Area((accelerator.parameter,accelerator.dEzdz(accelerator.parameter)), kdims=dim_z, vdims=dim_dEzdz)
z_Bz = hv.Area((accelerator.parameter,accelerator.Bz(accelerator.parameter)), kdims=dim_z, vdims=dim_Bz)
z_r = hv.Area(((accelerator.parameter,simulation.envelope_x*1e3)), kdims=[dim_z], vdims=[dim_r], group='Beam')
z_x_particle = hv.Curve(((accelerator.parameter,simulation.particle_x['Center']*1e3)), kdims=[dim_z], vdims=[dim_r], group='Beam')
z_y_particle = hv.Curve(((accelerator.parameter,simulation.particle_y['Center']*1e3)), kdims=[dim_z], vdims=[dim_r], group='Beam')
z_phase = hv.Curve(((accelerator.parameter,simulation.particle_phase['Center'])), kdims=[dim_z], vdims=[dim_phase])

(z_x_particle*z_y_particle+z_phase+z_Bz+z_Ez+z_dEzdz).cols(1)
# Out:
# :Layout
#    .Beam.I   :Overlay
#       .Beam.I  :Curve   [z]   (r)
#       .Beam.II :Curve   [z]   (r)
#    .Curve.I  :Curve   [z]   ($\phi$)
#    .Area.I   :Area   [z]   (Bz)
#    .Area.II  :Area   [z]   (Ez)
#    .Area.III :Area   [z]   (dEzdz)
